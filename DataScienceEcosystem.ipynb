# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# | Data Science Tools |
# |---------------------|
# | Jupyter Notebook    |
# | RStudio             |
# | Apache Zeppelin     |

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
(3*4)+5
# This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %%
200/6
# This will convert 200 minutes to hours by dividing by 60
# Out:
# 33.333333333333336

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Describe key uses of Python in Data Science
# - Explain the role of R and SQL in data analysis
# - Understand the difference between open source and free software
# - Identify tools and environments used by data scientists

# %% [markdown]
# <h2>Author</h2>
# Ram Kumar
